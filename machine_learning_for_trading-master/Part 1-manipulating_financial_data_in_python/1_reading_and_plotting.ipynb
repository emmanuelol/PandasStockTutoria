# %%
import os
import plotly as py
import plotly.graph_objs as go

from datetime import datetime
import pandas_datareader.data as web
def get_max_close(symbol):
    """return the max close value for stock indicated by symbol"""
    df = pd.read_csv("data/{}.csv".format(symbol)) 
    return df['Close'].max()  # compute and return max
    #return df['Volume'].mean()  # compute and return mean
    
    
def test_run():
    """Function called by Test Run"""
    for symbol in ['AAPL', 'IBM']:
        print ("Mean close")
        print (symbol, get_max_close(symbol))

if __name__ == "__main__":
    test_run()
# Out:
# Mean close
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-db0a68cd7dca> in <module>()
#      19
#      20 if __name__ == "__main__":
# ---> 21     test_run()
#
# <ipython-input-2-db0a68cd7dca> in test_run()
#      16     for symbol in ['AAPL', 'IBM']:
#      17         print ("Mean close")
# ---> 18         print (symbol, get_max_close(symbol))
#      19
#      20 if __name__ == "__main__":
#
# <ipython-input-2-db0a68cd7dca> in get_max_close(symbol)
#       7 def get_max_close(symbol):
#       8     """return the max close value for stock indicated by symbol"""
# ----> 9     df = pd.read_csv("data/{}.csv".format(symbol))
#      10     return df['Close'].max()  # compute and return max
#      11     #return df['Volume'].mean()  # compute and return mean
#
# NameError: global name 'pd' is not defined

# %%
import pandas as pd

def test_run():
    df = pd.read_csv("data/AAPL.csv")
    print (df.tail(5))  # last 5 rows
    #print df[10:21] # row 10 to 20
    
if __name__ == "__main__":
    test_run()
# Out:
#             Date    Open    High     Low   Close    Volume  Adj Close
# 3170  2000-02-07  108.00  114.25  105.94  114.06  15770800      28.39
# 3171  2000-02-04  103.94  110.00  103.62  108.00  15206800      26.88
# 3172  2000-02-03  100.31  104.25  100.25  103.31  16977600      25.72
# 3173  2000-02-02  100.75  102.12   97.00   98.81  16588800      24.60
# 3174  2000-02-01  104.00  105.00  100.00  100.25  11380000      24.96

# %%
# goal -> obtain mean volume
def get_mean_volume(symbol):
    """Return the mean volume for stock indicated by symbol"""
    df = pd.read_csv("data/{}.csv".format(symbol))
    return df['Volume'].mean()

def test_run():
    """Function called by Test Run"""
    for symbol in ['AAPL', 'IBM']:
        print( "Mean Volume")
        print(symbol, get_mean_volume(symbol))
        
if __name__ == "__main__":
    test_run()
# Out:
# Mean Volume
# ('AAPL', 21491431.338582676)
# Mean Volume
# ('IBM', 7103570.8031496061)

# %%
"""Plot High prices for IBM"""
import matplotlib.pyplot as plt

def test_run():
    df = pd.read_csv("data/IBM.csv")
    #print df['Adj Close']
    df['High'].plot()  # plot high IBM prices
    plt.show()
        
if __name__ == "__main__":
    test_run()

# %%
import pandas as pd
import matplotlib.pyplot as plt

def test_run():
    df = pd.read_csv("data/AAPL.csv")
    #print df['Adj Close']
    df['Adj Close'].plot()
    # plots are in reverse order
    plt.show()
        
if __name__ == "__main__":
    test_run()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-36466fc70078> in <module>()
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3
#       4 def test_run():
#       5     df = pd.read_csv("data/AAPL.csv")
#
# ImportError: No module named matplotlib.pyplot

# %%
"""Plot two columns"""
import matplotlib.pyplot as plt

def test_run():
    df = pd.read_csv("data/AAPL.csv")
    #print df['Adj Close']
    df[['Close', 'Adj Close']].plot()  # plot Close and Adj close AAPl prices
    plt.show()
        
if __name__ == "__main__":
    test_run()
